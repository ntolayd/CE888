# %% [markdown]
# <a href="https://colab.research.google.com/github/ntolayd/CE888/blob/main/Assignment1/fire_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip "/content/gdrive/My Drive/Test.zip"
# !unzip "/content/gdrive/My Drive/Training.zip"

# %%
import numpy as np
from tqdm import tqdm
from random import shuffle
import cv2
import os 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# %%
Train_path = 'Training'
Test_path = 'Test'

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
                                   

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    Train_path,
    color_mode='rgb',
    class_mode='binary') # set as training data


test_generator = test_datagen.flow_from_directory(
        Test_path,
        color_mode='rgb',
        class_mode='binary')
# Out:
# Found 39375 images belonging to 2 classes.
# Found 8617 images belonging to 2 classes.

# %%
print(len(os.listdir('Training/Fire')))
print(len(os.listdir('Training/No_Fire')))
print(len(os.listdir('Test/Fire')))
print(len(os.listdir('Test/No_Fire')))
# Out:
# 25018
# 14357
# 5137
# 3480

# %%
example_training_fire = cv2.imread('Training/Fire/resized_frame8886.jpg')
example_training_no_fire = cv2.imread('Training/No_Fire/resized_frame3599.jpg')
example_test_fire = cv2.imread('Test/Fire/resized_test_fire_frame1366.jpg')
example_test_no_fire = cv2.imread('Test/No_Fire/resized_test_nofire_frame1134.jpg')

# %%
example_test_no_fire.shape
# Out:
# (254, 254, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(example_test_fire)
# Out:
# <PIL.Image.Image image mode=RGB size=254x254 at 0x7F0F3B0DFC10>

# %%
cv2_imshow(example_test_no_fire)
# Out:
# <PIL.Image.Image image mode=RGB size=254x254 at 0x7F0F3B0DFB50>
